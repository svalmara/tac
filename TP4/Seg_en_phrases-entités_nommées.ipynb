# %% [markdown]
# # Segmentation en phrases

# %% [markdown]
# ## Imports

# %%
import os
import sys
import nltk
from nltk.tokenize import sent_tokenize
from collections import defaultdict
import spacy
from spacy.lang.fr.examples import sentences

# %%
nlp = spacy.load('fr_core_news_md')

# %% [markdown]
# ## Fichiers d'inputs et d'outputs

# %%
# Lister les Fichiers
title = "Art_1880-1960"
txt_path = '../data/txt'
files = os.listdir(data_path)

# %%
ext = ["Bxl_188", "Bxl_196"]

# %%
# Enlever les fichiers qui ne contiennent pas RptAn
Art_files = [f for f in files if f.startswith(tuple(ext))]
len(bxl_files)
# Out:
# 610

# %%
# Lister les fichiers RptAn
Art_files[:10]
# Out:
# ['Bxl_1882_Tome_I2_Part_12.txt',
#  'Bxl_1961_Tome_RptAn_Part_4.txt',
#  'Bxl_1889_Tome_I2_Part_3.txt',
#  'Bxl_1963_Tome_RptAn_Part_5.txt',
#  'Bxl_1966_Tome_I2_Part_5.txt',
#  'Bxl_1967_Tome_II2_Part_10.txt',
#  'Bxl_1965_Tome_I_Part_8.txt',
#  'Bxl_1966_Tome_II2_Part_11.txt',
#  'Bxl_1963_Tome_II1_Part_6.txt',
#  'Bxl_1967_Tome_I1_Part_7.txt']

# %%
# Stocker le contenu de ces fichiers dans une liste
content_list = []
for txt in Art_files:
    with open(os.path.join(txt_path, txt), 'r') as f:
        content_list.append(f.read())

# %%
# Compter le nombre d'éléments (=fichiers) dans la liste
len(content_list)
# Out:
# 610

# %%
# Imprimer les 200 premiers caractères du contenu du premier fichier
content_list[0][:200]
# Out:
# 'Art. 74. — Subside à VAthénée royal : 82,000 francs.\nCette somme représente la part incombant à ia Ville dans\nle traitement des professeurs, ainsi que le montant des\nmenues dépenses.\nLe budget présent'

# %%
# Ecrire tout le contenu dans un fichier temporaire
temp_path = '../data/tmp_tp4'
if not os.path.exists(temp_path):
    os.mkdir(temp_path)
with open(os.path.join(temp_path, f'{title}.txt'), 'w') as f:
    f.write(' '.join(content_list))

# %%
# Imprimer le contenu du fichier et constater les "déchets"
with open(os.path.join(temp_path, f'{title}.txt'), 'r') as f:
    before = f.read()

before[:500]
# Out:
# "Art. 74. — Subside à VAthénée royal : 82,000 francs.\nCette somme représente la part incombant à ia Ville dans\nle traitement des professeurs, ainsi que le montant des\nmenues dépenses.\nLe budget présenté par la Commission administrative\nainsi que le compte justifiant l'emploi de ces fonds, sont\nannuellement soumis à l'approbation du Conseil communal.\nArt. 75. — loyer de locaux, entretien, contributions et assurance :\n29,750 francs.\nLoyer des locaux de la section professionnelle de 1 Athénée, rue d"

# %%
infile = "../data/tmp_tp4/Art_1880-1960.txt"
outfile = "../data/tmp_tp4/sents_tp4.txt"

# %% [markdown]
# ## Segmentation en phrases du corpus des années 1880 et 1960 et création d'un nouveau fichier

# %%
LIMIT = None

# %%
with open(outfile, 'w', encoding="utf-8") as output:
# Done

# %% [markdown]
# # Reconnaissance d'entités nommées avec SpaCy

# %%
text = open("../data/sents2_tp4.txt", encoding='utf-8').read()

# %%
# Traiter le texte
doc = nlp(text)

# %%
# Compter les entités
people = defaultdict(int)
for ent in doc.ents:
    if ent.label_ == "PER" and len(ent.text) > 3:
        people[ent.text] += 1

# %%
# Trier et imprimer

sorted_people = sorted(people.items(), key=lambda kv: kv[1], reverse=True)

for person, freq in sorted_people[:50]:
    print(f"{person} apparait {freq} fois dans le corpus")
# Out:
# Montant apparait 11 fois dans le corpus
# Subside apparait 10 fois dans le corpus
# Loyer apparait 8 fois dans le corpus
# Celte apparait 7 fois dans le corpus
# Messieurs apparait 7 fois dans le corpus
# Recettes apparait 6 fois dans le corpus
# Fabrique apparait 5 fois dans le corpus
# Jardin Zoologique apparait 4 fois dans le corpus
# Gouverneur apparait 4 fois dans le corpus
# Locations apparait 4 fois dans le corpus
# Propriétés apparait 3 fois dans le corpus
# lpar 250 apparait 3 fois dans le corpus
# Relevé apparait 3 fois dans le corpus
# Haeren apparait 3 fois dans le corpus
# Mosnier apparait 3 fois dans le corpus
# Recette apparait 3 fois dans le corpus
# Charles-Quint apparait 3 fois dans le corpus
# Eglise Saint-Josse apparait 3 fois dans le corpus
# Receveur apparait 2 fois dans le corpus
# Minque apparait 2 fois dans le corpus
# Thisselt apparait 2 fois dans le corpus
# Gudule apparait 2 fois dans le corpus
# Constructions apparait 2 fois dans le corpus
# M. Wauters apparait 2 fois dans le corpus
# t. III apparait 2 fois dans le corpus
# Eglise Sainte-Catherine apparait 2 fois dans le corpus
# Budget apparait 2 fois dans le corpus
# De Mot apparait 2 fois dans le corpus
# M. l'Echevin Walravens apparait 2 fois dans le corpus
# ia Ville apparait 1 fois dans le corpus
# Eglise de Notre-Dame de la Chapelle apparait 1 fois dans le corpus
# Eglise de Notre-Dame apparait 1 fois dans le corpus
# Eglise de Notre-Dame de Bon-Secours apparait 1 fois dans le corpus
# A. Propriétés apparait 1 fois dans le corpus
# B. Terrains apparait 1 fois dans le corpus
# Asile des Petites-Sœurs apparait 1 fois dans le corpus
# Caroly apparait 1 fois dans le corpus
# KEMBOURSÉES apparait 1 fois dans le corpus
# A. REMBOURSER apparait 1 fois dans le corpus
# u i t é apparait 1 fois dans le corpus
# Dette apparait 1 fois dans le corpus
# Revenus apparait 1 fois dans le corpus
# Pensionnés apparait 1 fois dans le corpus
# Scholtès apparait 1 fois dans le corpus
# Bouillon apparait 1 fois dans le corpus
# De Doncker apparait 1 fois dans le corpus
# Bossuet apparait 1 fois dans le corpus
# Desmedt apparait 1 fois dans le corpus
# De Marbaix apparait 1 fois dans le corpus
# De Forseau apparait 1 fois dans le corpus

# %% [markdown]
# # Segmentation en phrases pour la décennie 1880

# %%
infile = "../data/tmp_tp4/1880s.txt"
outfile = "../data/tmp_tp4/sents_1880_tp4.txt"

# %%
LIMIT = 1000000

# %%
with open(outfile, 'w', encoding="utf-8") as output:
    with open(infile, encoding="utf-8", errors="backslashreplace") as f:
        content = f.readlines()
        content = content[:LIMIT] if LIMIT is not None else content
        n_lines = len(content)
        for i, line in enumerate(content):
            if i % 10000 == 0:
                print(f'processing line {i}/{n_lines}')
            sentences = sent_tokenize(line)
            for sent in sentences:
                output.write(sent + "\n")
print("Done")
# Out:
# processing line 0/1000000
# processing line 10000/1000000
# processing line 20000/1000000
# processing line 30000/1000000
# processing line 40000/1000000
# processing line 50000/1000000
# processing line 60000/1000000
# processing line 70000/1000000
# processing line 80000/1000000
# processing line 90000/1000000
# processing line 100000/1000000
# processing line 110000/1000000
# processing line 120000/1000000
# processing line 130000/1000000
# processing line 140000/1000000
# processing line 150000/1000000
# processing line 160000/1000000
# processing line 170000/1000000
# processing line 180000/1000000
# processing line 190000/1000000
# processing line 200000/1000000
# processing line 210000/1000000
# processing line 220000/1000000
# processing line 230000/1000000
# processing line 240000/1000000
# processing line 250000/1000000
# processing line 260000/1000000
# processing line 270000/1000000
# processing line 280000/1000000
# processing line 290000/1000000
# processing line 300000/1000000
# processing line 310000/1000000
# processing line 320000/1000000
# processing line 330000/1000000
# processing line 340000/1000000
# processing line 350000/1000000
# processing line 360000/1000000
# processing line 370000/1000000
# processing line 380000/1000000
# processing line 390000/1000000
# processing line 400000/1000000
# processing line 410000/1000000
# processing line 420000/1000000
# processing line 430000/1000000
# processing line 440000/1000000
# processing line 450000/1000000
# processing line 460000/1000000
# processing line 470000/1000000
# processing line 480000/1000000
# processing line 490000/1000000
# processing line 500000/1000000
# processing line 510000/1000000
# processing line 520000/1000000
# processing line 530000/1000000
# processing line 540000/1000000
# processing line 550000/1000000
# processing line 560000/1000000
# processing line 570000/1000000
# processing line 580000/1000000
# processing line 590000/1000000
# processing line 600000/1000000
# processing line 610000/1000000
# processing line 620000/1000000
# processing line 630000/1000000
# processing line 640000/1000000
# processing line 650000/1000000
# processing line 660000/1000000
# processing line 670000/1000000
# processing line 680000/1000000
# processing line 690000/1000000
# processing line 700000/1000000
# processing line 710000/1000000
# processing line 720000/1000000
# processing line 730000/1000000
# processing line 740000/1000000
# processing line 750000/1000000
# processing line 760000/1000000
# processing line 770000/1000000
# processing line 780000/1000000
# processing line 790000/1000000
# processing line 800000/1000000
# processing line 810000/1000000
# processing line 820000/1000000
# processing line 830000/1000000
# processing line 840000/1000000
# processing line 850000/1000000
# processing line 860000/1000000
# processing line 870000/1000000
# processing line 880000/1000000
# processing line 890000/1000000
# processing line 900000/1000000
# processing line 910000/1000000
# processing line 920000/1000000
# processing line 930000/1000000
# processing line 940000/1000000
# processing line 950000/1000000
# processing line 960000/1000000
# processing line 970000/1000000
# processing line 980000/1000000
# processing line 990000/1000000
# Done

# %% [markdown]
# # Segmentation en phrases pour la décennie 1960

# %%
infile = "../data/tmp_tp4/1960s.txt"
outfile = "../data/tmp_tp4/sents_1960_tp4.txt"

# %%
LIMIT = 1000000

# %%
with open(outfile, 'w', encoding="utf-8") as output:
    with open(infile, encoding="utf-8", errors="backslashreplace") as f:
        content = f.readlines()
        content = content[:LIMIT] if LIMIT is not None else content
        n_lines = len(content)
        for i, line in enumerate(content):
            if i % 10000 == 0:
                print(f'processing line {i}/{n_lines}')
            sentences = sent_tokenize(line)
            for sent in sentences:
                output.write(sent + "\n")
print("Done")
# Out:
# processing line 0/1000000
# processing line 10000/1000000
# processing line 20000/1000000
# processing line 30000/1000000
# processing line 40000/1000000
# processing line 50000/1000000
# processing line 60000/1000000
# processing line 70000/1000000
# processing line 80000/1000000
# processing line 90000/1000000
# processing line 100000/1000000
# processing line 110000/1000000
# processing line 120000/1000000
# processing line 130000/1000000
# processing line 140000/1000000
# processing line 150000/1000000
# processing line 160000/1000000
# processing line 170000/1000000
# processing line 180000/1000000
# processing line 190000/1000000
# processing line 200000/1000000
# processing line 210000/1000000
# processing line 220000/1000000
# processing line 230000/1000000
# processing line 240000/1000000
# processing line 250000/1000000
# processing line 260000/1000000
# processing line 270000/1000000
# processing line 280000/1000000
# processing line 290000/1000000
# processing line 300000/1000000
# processing line 310000/1000000
# processing line 320000/1000000
# processing line 330000/1000000
# processing line 340000/1000000
# processing line 350000/1000000
# processing line 360000/1000000
# processing line 370000/1000000
# processing line 380000/1000000
# processing line 390000/1000000
# processing line 400000/1000000
# processing line 410000/1000000
# processing line 420000/1000000
# processing line 430000/1000000
# processing line 440000/1000000
# processing line 450000/1000000
# processing line 460000/1000000
# processing line 470000/1000000
# processing line 480000/1000000
# processing line 490000/1000000
# processing line 500000/1000000
# processing line 510000/1000000
# processing line 520000/1000000
# processing line 530000/1000000
# processing line 540000/1000000
# processing line 550000/1000000
# processing line 560000/1000000
# processing line 570000/1000000
# processing line 580000/1000000
# processing line 590000/1000000
# processing line 600000/1000000
# processing line 610000/1000000
# processing line 620000/1000000
# processing line 630000/1000000
# processing line 640000/1000000
# processing line 650000/1000000
# processing line 660000/1000000
# processing line 670000/1000000
# processing line 680000/1000000
# processing line 690000/1000000
# processing line 700000/1000000
# processing line 710000/1000000
# processing line 720000/1000000
# processing line 730000/1000000
# processing line 740000/1000000
# processing line 750000/1000000
# processing line 760000/1000000
# processing line 770000/1000000
# processing line 780000/1000000
# processing line 790000/1000000
# processing line 800000/1000000
# processing line 810000/1000000
# processing line 820000/1000000
# processing line 830000/1000000
# processing line 840000/1000000
# processing line 850000/1000000
# processing line 860000/1000000
# processing line 870000/1000000
# processing line 880000/1000000
# processing line 890000/1000000
# processing line 900000/1000000
# processing line 910000/1000000
# processing line 920000/1000000
# processing line 930000/1000000
# processing line 940000/1000000
# processing line 950000/1000000
# processing line 960000/1000000
# processing line 970000/1000000
# processing line 980000/1000000
# processing line 990000/1000000
# Done
